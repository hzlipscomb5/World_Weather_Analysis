# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#Pairing cities with our random coordinates
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters. (In the code block, we have initialized the counters at 1 because we want the first iteration of the logging for each recorded response and the set to start at 1.)
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.(endpart is formatting)
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | bumba
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | grindavik
# Processing Record 6 of Set 1 | westport
# Processing Record 7 of Set 1 | qaqortoq
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | sibolga
# Processing Record 10 of Set 1 | lannion
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 1 | chowchilla
# Processing Record 23 of Set 1 | campoverde
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | oriximina
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | sao filipe
# Processing Record 28 of Set 1 | sao felix do xingu
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | dunedin
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | san andres
# Processing Record 35 of Set 1 | clyde river
# Processing Record 36 of Set 1 | tommot
# Processing Record 37 of Set 1 | amahai
# Processing Record 38 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | hervey bay
# Processing Record 41 of Set 1 | tura
# Processing Record 42 of Set 1 | broome
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | tonantins
# Processing Record 45 of Set 1 | chatellerault
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | port-gentil
# Processing Record 50 of Set 1 | thinadhoo
# Processing Record 1 of Set 2 | ambilobe
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | southampton
# Processing Record 4 of Set 2 | rocha
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | kysyl-syr
# Processing Record 7 of Set 2 | naze
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | korem
# Processing Record 11 of Set 2 | pacifica
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | ndende
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | gorontalo
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | biltine
# Processing Record 19 of Set 2 | lompoc
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | galich
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | vestmannaeyjar
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 2 | bonnyville
# Processing Record 32 of Set 2 | saquena
# Processing Record 33 of Set 2 | santa isabel do rio negro
# Processing Record 34 of Set 2 | pullman
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 2 | smithers
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | antofagasta
# Processing Record 39 of Set 2 | cap-aux-meules
# Processing Record 40 of Set 2 | marquette
# Processing Record 41 of Set 2 | ust-nera
# Processing Record 42 of Set 2 | plainview
# Processing Record 43 of Set 2 | cabra
# Processing Record 44 of Set 2 | port blair
# Processing Record 45 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | haverfordwest
# Processing Record 48 of Set 2 | mezen
# Processing Record 49 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | nara
# Processing Record 2 of Set 3 | price
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | kalmunai
# Processing Record 5 of Set 3 | lokosovo
# Processing Record 6 of Set 3 | banjarmasin
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | hamilton
# Processing Record 9 of Set 3 | merauke
# Processing Record 10 of Set 3 | pangnirtung
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | lasa
# Processing Record 13 of Set 3 | tyret pervaya
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | isfana
# Processing Record 18 of Set 3 | tecoanapa
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | zhigansk
# Processing Record 21 of Set 3 | mahibadhoo
# Processing Record 22 of Set 3 | lorengau
# Processing Record 23 of Set 3 | namie
# Processing Record 24 of Set 3 | churapcha
# Processing Record 25 of Set 3 | medvedok
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | khaniotis
# Processing Record 29 of Set 3 | atambua
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | obo
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | nakhon pathom
# Processing Record 34 of Set 3 | vila velha
# Processing Record 35 of Set 3 | padang
# Processing Record 36 of Set 3 | awbari
# Processing Record 37 of Set 3 | sabang
# Processing Record 38 of Set 3 | mecca
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | san patricio
# Processing Record 41 of Set 3 | cherskiy
# Processing Record 42 of Set 3 | balikpapan
# Processing Record 43 of Set 3 | yumen
# Processing Record 44 of Set 3 | mbuji-mayi
# Processing Record 45 of Set 3 | nikolskoye
# Processing Record 46 of Set 3 | gwadar
# Processing Record 47 of Set 3 | kahului
# Processing Record 48 of Set 3 | simbahan
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | ketchikan
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | christchurch
# Processing Record 3 of Set 4 | codrington
# Processing Record 4 of Set 4 | ayan
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | bulawayo
# Processing Record 7 of Set 4 | saint-joseph
# Processing Record 8 of Set 4 | los llanos de aridane
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | caruray
# Processing Record 11 of Set 4 | ellisras
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | mae hong son
# Processing Record 14 of Set 4 | sur
# Processing Record 15 of Set 4 | yellowknife
# Processing Record 16 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 4 | emerald
# Processing Record 18 of Set 4 | kemijarvi
# Processing Record 19 of Set 4 | karwar
# Processing Record 20 of Set 4 | hokitika
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | swellendam
# Processing Record 23 of Set 4 | kargil
# Processing Record 24 of Set 4 | keuruu
# Processing Record 25 of Set 4 | zaraza
# Processing Record 26 of Set 4 | livingston
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | guaymas
# Processing Record 29 of Set 4 | bandarbeyla
# Processing Record 30 of Set 4 | aklavik
# Processing Record 31 of Set 4 | puerto leguizamo
# Processing Record 32 of Set 4 | fort nelson
# Processing Record 33 of Set 4 | zhigalovo
# Processing Record 34 of Set 4 | roald
# Processing Record 35 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | dingle
# Processing Record 38 of Set 4 | sakyla
# Processing Record 39 of Set 4 | hasaki
# Processing Record 40 of Set 4 | owando
# Processing Record 41 of Set 4 | gornopravdinsk
# Processing Record 42 of Set 4 | esso
# Processing Record 43 of Set 4 | dalvik
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | tuatapere
# Processing Record 46 of Set 4 | lavrentiya
# Processing Record 47 of Set 4 | isangel
# Processing Record 48 of Set 4 | sambava
# Processing Record 49 of Set 4 | lagoa
# Processing Record 50 of Set 4 | faanui
# Processing Record 1 of Set 5 | shingu
# Processing Record 2 of Set 5 | erzin
# Processing Record 3 of Set 5 | leningradskiy
# Processing Record 4 of Set 5 | hachinohe
# Processing Record 5 of Set 5 | bluff
# Processing Record 6 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 5 | maceio
# Processing Record 8 of Set 5 | yerbogachen
# Processing Record 9 of Set 5 | henties bay
# Processing Record 10 of Set 5 | saveh
# Processing Record 11 of Set 5 | hoopstad
# Processing Record 12 of Set 5 | meulaboh
# Processing Record 13 of Set 5 | cururupu
# Processing Record 14 of Set 5 | kottayam
# Processing Record 15 of Set 5 | havre-saint-pierre
# Processing Record 16 of Set 5 | pascagoula
# Processing Record 17 of Set 5 | chumikan
# Processing Record 18 of Set 5 | vanimo
# Processing Record 19 of Set 5 | ploemeur
# Processing Record 20 of Set 5 | provideniya
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | tsiroanomandidy
# Processing Record 23 of Set 5 | tazovskiy
# Processing Record 24 of Set 5 | gashua
# Processing Record 25 of Set 5 | santa rosa
# Processing Record 26 of Set 5 | beya
# Processing Record 27 of Set 5 | namatanai
# Processing Record 28 of Set 5 | tilichiki
# Processing Record 29 of Set 5 | taoudenni
# Processing Record 30 of Set 5 | yulara
# Processing Record 31 of Set 5 | souillac
# Processing Record 32 of Set 5 | baniyas
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | coihaique
# Processing Record 35 of Set 5 | qandala
# Processing Record 36 of Set 5 | montepuez
# Processing Record 37 of Set 5 | ornskoldsvik
# Processing Record 38 of Set 5 | mitsamiouli
# Processing Record 39 of Set 5 | baillif
# Processing Record 40 of Set 5 | clyde
# Processing Record 41 of Set 5 | himora
# City not found. Skipping...
# Processing Record 42 of Set 5 | bilibino
# Processing Record 43 of Set 5 | fishers
# Processing Record 44 of Set 5 | kaitangata
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | shelburne
# Processing Record 47 of Set 5 | alice springs
# Processing Record 48 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 5 | bandiagara
# Processing Record 50 of Set 5 | inirida
# Processing Record 1 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 6 | jumla
# Processing Record 3 of Set 6 | katsuura
# Processing Record 4 of Set 6 | cairo
# Processing Record 5 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 6 | hovd
# Processing Record 7 of Set 6 | sorland
# Processing Record 8 of Set 6 | kieta
# Processing Record 9 of Set 6 | douglas
# Processing Record 10 of Set 6 | lerwick
# Processing Record 11 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 12 of Set 6 | coos bay
# Processing Record 13 of Set 6 | laguna
# Processing Record 14 of Set 6 | mongo
# Processing Record 15 of Set 6 | san quintin
# Processing Record 16 of Set 6 | along
# Processing Record 17 of Set 6 | okhotsk
# Processing Record 18 of Set 6 | okato
# Processing Record 19 of Set 6 | beringovskiy
# Processing Record 20 of Set 6 | gonda
# Processing Record 21 of Set 6 | margate
# Processing Record 22 of Set 6 | khulo
# Processing Record 23 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 25 of Set 6 | ambunti
# Processing Record 26 of Set 6 | xining
# Processing Record 27 of Set 6 | khatanga
# Processing Record 28 of Set 6 | tadine
# Processing Record 29 of Set 6 | constitucion
# Processing Record 30 of Set 6 | ostrovnoy
# Processing Record 31 of Set 6 | baykit
# Processing Record 32 of Set 6 | kralendijk
# Processing Record 33 of Set 6 | kuldur
# Processing Record 34 of Set 6 | carnarvon
# Processing Record 35 of Set 6 | ancud
# Processing Record 36 of Set 6 | upata
# Processing Record 37 of Set 6 | poum
# Processing Record 38 of Set 6 | pozo colorado
# Processing Record 39 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 6 | hofn
# Processing Record 41 of Set 6 | sao joao da barra
# Processing Record 42 of Set 6 | esperance
# Processing Record 43 of Set 6 | matamoros
# Processing Record 44 of Set 6 | mogadishu
# Processing Record 45 of Set 6 | saint anthony
# Processing Record 46 of Set 6 | fortuna
# Processing Record 47 of Set 6 | saint george
# Processing Record 48 of Set 6 | longyearbyen
# Processing Record 49 of Set 6 | lyskovo
# Processing Record 50 of Set 6 | saint-augustin
# Processing Record 1 of Set 7 | kavieng
# Processing Record 2 of Set 7 | hualmay
# Processing Record 3 of Set 7 | puerto ayora
# Processing Record 4 of Set 7 | husavik
# Processing Record 5 of Set 7 | egvekinot
# Processing Record 6 of Set 7 | vostok
# Processing Record 7 of Set 7 | krasnoselkup
# Processing Record 8 of Set 7 | antalaha
# Processing Record 9 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 7 | shenjiamen
# Processing Record 11 of Set 7 | cidreira
# Processing Record 12 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 7 | nigran
# Processing Record 14 of Set 7 | chuy
# Processing Record 15 of Set 7 | duki
# Processing Record 16 of Set 7 | casablanca
# Processing Record 17 of Set 7 | cochabamba
# Processing Record 18 of Set 7 | ferrol
# Processing Record 19 of Set 7 | paamiut
# Processing Record 20 of Set 7 | itarema
# Processing Record 21 of Set 7 | elbrus
# Processing Record 22 of Set 7 | niquero
# Processing Record 23 of Set 7 | bathsheba
# Processing Record 24 of Set 7 | quatre cocos
# Processing Record 25 of Set 7 | noumea
# Processing Record 26 of Set 7 | port macquarie
# Processing Record 27 of Set 7 | kyabe
# Processing Record 28 of Set 7 | ilhabela
# Processing Record 29 of Set 7 | byron bay
# Processing Record 30 of Set 7 | voh
# Processing Record 31 of Set 7 | kamaishi
# Processing Record 32 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 7 | cedar city
# Processing Record 34 of Set 7 | vanino
# Processing Record 35 of Set 7 | half moon bay
# Processing Record 36 of Set 7 | san ramon de la nueva oran
# Processing Record 37 of Set 7 | tres arroyos
# Processing Record 38 of Set 7 | norman wells
# Processing Record 39 of Set 7 | saldanha
# Processing Record 40 of Set 7 | port hedland
# Processing Record 41 of Set 7 | grand gaube
# Processing Record 42 of Set 7 | kenai
# Processing Record 43 of Set 7 | comodoro rivadavia
# Processing Record 44 of Set 7 | ihosy
# Processing Record 45 of Set 7 | horsham
# Processing Record 46 of Set 7 | ozernovskiy
# Processing Record 47 of Set 7 | tuy hoa
# Processing Record 48 of Set 7 | kavaratti
# Processing Record 49 of Set 7 | seara
# Processing Record 50 of Set 7 | changji
# Processing Record 1 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 8 | olafsvik
# Processing Record 4 of Set 8 | hami
# Processing Record 5 of Set 8 | cayenne
# Processing Record 6 of Set 8 | machico
# Processing Record 7 of Set 8 | saint-prosper
# Processing Record 8 of Set 8 | manching
# Processing Record 9 of Set 8 | marzuq
# Processing Record 10 of Set 8 | moerai
# Processing Record 11 of Set 8 | altay
# Processing Record 12 of Set 8 | klyuchi
# Processing Record 13 of Set 8 | north bend
# Processing Record 14 of Set 8 | beni
# Processing Record 15 of Set 8 | buenos aires
# Processing Record 16 of Set 8 | rio gallegos
# Processing Record 17 of Set 8 | stornoway
# Processing Record 18 of Set 8 | winslow
# Processing Record 19 of Set 8 | altamura
# Processing Record 20 of Set 8 | abu samrah
# Processing Record 21 of Set 8 | sault sainte marie
# Processing Record 22 of Set 8 | uvinza
# Processing Record 23 of Set 8 | muros
# Processing Record 24 of Set 8 | kasongo-lunda
# Processing Record 25 of Set 8 | pesaro
# Processing Record 26 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 8 | kruisfontein
# Processing Record 28 of Set 8 | bratsk
# Processing Record 29 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 8 | san policarpo
# Processing Record 31 of Set 8 | ossora
# Processing Record 32 of Set 8 | nieuw nickerie
# Processing Record 33 of Set 8 | port lincoln
# Processing Record 34 of Set 8 | portland
# Processing Record 35 of Set 8 | banda aceh
# Processing Record 36 of Set 8 | kamenka
# Processing Record 37 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 8 | asau
# Processing Record 39 of Set 8 | kiunga
# Processing Record 40 of Set 8 | sola
# Processing Record 41 of Set 8 | nhulunbuy
# Processing Record 42 of Set 8 | gigmoto
# Processing Record 43 of Set 8 | faya
# Processing Record 44 of Set 8 | hargeysa
# Processing Record 45 of Set 8 | mundo nuevo
# Processing Record 46 of Set 8 | san pedro
# Processing Record 47 of Set 8 | sines
# Processing Record 48 of Set 8 | luwuk
# Processing Record 49 of Set 8 | kaitong
# Processing Record 50 of Set 8 | sioux lookout
# Processing Record 1 of Set 9 | mehamn
# Processing Record 2 of Set 9 | igrim
# Processing Record 3 of Set 9 | alofi
# Processing Record 4 of Set 9 | yershichi
# Processing Record 5 of Set 9 | east stroudsburg
# Processing Record 6 of Set 9 | port-cartier
# Processing Record 7 of Set 9 | road town
# Processing Record 8 of Set 9 | lufilufi
# Processing Record 9 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 9 | rio de janeiro
# Processing Record 11 of Set 9 | avera
# Processing Record 12 of Set 9 | pisco
# Processing Record 13 of Set 9 | samarai
# Processing Record 14 of Set 9 | khani
# Processing Record 15 of Set 9 | axim
# Processing Record 16 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 9 | ilulissat
# Processing Record 18 of Set 9 | borovoy
# Processing Record 19 of Set 9 | mahabaleshwar
# Processing Record 20 of Set 9 | gravdal
# Processing Record 21 of Set 9 | pochutla
# Processing Record 22 of Set 9 | shuangyang
# Processing Record 23 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 9 | nivala
# Processing Record 25 of Set 9 | providencia
# Processing Record 26 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 9 | uhlove
# Processing Record 28 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 9 | berlevag
# Processing Record 30 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 9 | bilma
# Processing Record 32 of Set 9 | wakkanai
# Processing Record 33 of Set 9 | adrar
# Processing Record 34 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 9 | pangoa
# Processing Record 36 of Set 9 | kapoeta
# Processing Record 37 of Set 9 | komsomolskiy
# Processing Record 38 of Set 9 | luau
# Processing Record 39 of Set 9 | urdoma
# Processing Record 40 of Set 9 | ulyanovo
# City not found. Skipping...
# Processing Record 41 of Set 9 | wewak
# Processing Record 42 of Set 9 | pingzhuang
# Processing Record 43 of Set 9 | riyadh
# Processing Record 44 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 9 | hobyo
# Processing Record 46 of Set 9 | mildura
# Processing Record 47 of Set 9 | albox
# Processing Record 48 of Set 9 | roebourne
# Processing Record 49 of Set 9 | rio tercero
# Processing Record 50 of Set 9 | deyang
# Processing Record 1 of Set 10 | abha
# Processing Record 2 of Set 10 | cooma
# Processing Record 3 of Set 10 | kortkeros
# Processing Record 4 of Set 10 | luanda
# Processing Record 5 of Set 10 | fallon
# Processing Record 6 of Set 10 | wawa
# Processing Record 7 of Set 10 | north platte
# Processing Record 8 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 10 | hay river
# Processing Record 10 of Set 10 | sao francisco de assis
# Processing Record 11 of Set 10 | batabano
# Processing Record 12 of Set 10 | svetlyy
# Processing Record 13 of Set 10 | iskilip
# Processing Record 14 of Set 10 | sakakah
# Processing Record 15 of Set 10 | alta floresta
# Processing Record 16 of Set 10 | bosaso
# Processing Record 17 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 10 | manakara
# Processing Record 19 of Set 10 | vuktyl
# Processing Record 20 of Set 10 | oussouye
# Processing Record 21 of Set 10 | gori
# Processing Record 22 of Set 10 | kendari
# Processing Record 23 of Set 10 | whitefish
# Processing Record 24 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 25 of Set 10 | salinopolis
# Processing Record 26 of Set 10 | yar-sale
# Processing Record 27 of Set 10 | inhambane
# Processing Record 28 of Set 10 | aswan
# Processing Record 29 of Set 10 | merke
# Processing Record 30 of Set 10 | sarangpur
# Processing Record 31 of Set 10 | magdagachi
# Processing Record 32 of Set 10 | bessonovka
# Processing Record 33 of Set 10 | champerico
# Processing Record 34 of Set 10 | fare
# Processing Record 35 of Set 10 | marawi
# Processing Record 36 of Set 10 | ferme-neuve
# Processing Record 37 of Set 10 | anito
# Processing Record 38 of Set 10 | gazli
# Processing Record 39 of Set 10 | santa marta
# Processing Record 40 of Set 10 | aykhal
# Processing Record 41 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 10 | touros
# Processing Record 43 of Set 10 | cabo san lucas
# Processing Record 44 of Set 10 | dicabisagan
# Processing Record 45 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 46 of Set 10 | piotrkow trybunalski
# Processing Record 47 of Set 10 | sosva
# Processing Record 48 of Set 10 | vestmanna
# Processing Record 49 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 10 | konya
# Processing Record 1 of Set 11 | bagan
# Processing Record 2 of Set 11 | mackenzie
# Processing Record 3 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 11 | jamuria
# Processing Record 5 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 6 of Set 11 | vila franca do campo
# Processing Record 7 of Set 11 | leninsk
# Processing Record 8 of Set 11 | gongzhuling
# Processing Record 9 of Set 11 | kununurra
# Processing Record 10 of Set 11 | lernanist
# Processing Record 11 of Set 11 | roma
# Processing Record 12 of Set 11 | moron
# Processing Record 13 of Set 11 | nanakuli
# Processing Record 14 of Set 11 | paranaiba
# Processing Record 15 of Set 11 | boyolangu
# Processing Record 16 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 11 | maumere
# Processing Record 18 of Set 11 | taltal
# Processing Record 19 of Set 11 | alexandria
# Processing Record 20 of Set 11 | villaviciosa
# Processing Record 21 of Set 11 | saint-pierre
# Processing Record 22 of Set 11 | banamba
# Processing Record 23 of Set 11 | ewa beach
# Processing Record 24 of Set 11 | marsh harbour
# Processing Record 25 of Set 11 | dongli
# Processing Record 26 of Set 11 | syasstroy
# Processing Record 27 of Set 11 | saravan
# Processing Record 28 of Set 11 | nebbi
# Processing Record 29 of Set 11 | kuryk
# Processing Record 30 of Set 11 | lisala
# Processing Record 31 of Set 11 | bajil
# Processing Record 32 of Set 11 | ixtapa
# Processing Record 33 of Set 11 | rawson
# Processing Record 34 of Set 11 | stawell
# Processing Record 35 of Set 11 | nijar
# Processing Record 36 of Set 11 | barcelos
# Processing Record 37 of Set 11 | el prat de llobregat
# Processing Record 38 of Set 11 | bima
# Processing Record 39 of Set 11 | ngong
# Processing Record 40 of Set 11 | berezeni
# Processing Record 41 of Set 11 | xuddur
# Processing Record 42 of Set 11 | passagem franca
# Processing Record 43 of Set 11 | kushmurun
# Processing Record 44 of Set 11 | altus
# Processing Record 45 of Set 11 | fairbanks
# Processing Record 46 of Set 11 | yurimaguas
# Processing Record 47 of Set 11 | fayaoue
# Processing Record 48 of Set 11 | honggang
# Processing Record 49 of Set 11 | mar del plata
# Processing Record 50 of Set 11 | labuhan
# Processing Record 1 of Set 12 | raymondville
# Processing Record 2 of Set 12 | atar
# Processing Record 3 of Set 12 | guerrero negro
# Processing Record 4 of Set 12 | boa vista
# Processing Record 5 of Set 12 | aginskoye
# Processing Record 6 of Set 12 | simga
# Processing Record 7 of Set 12 | huangyan
# Processing Record 8 of Set 12 | silver city
# Processing Record 9 of Set 12 | aquiraz
# Processing Record 10 of Set 12 | moose factory
# Processing Record 11 of Set 12 | gat
# Processing Record 12 of Set 12 | madoc
# Processing Record 13 of Set 12 | praia da vitoria
# Processing Record 14 of Set 12 | charters towers
# Processing Record 15 of Set 12 | samana
# Processing Record 16 of Set 12 | muncar
# Processing Record 17 of Set 12 | prieska
# Processing Record 18 of Set 12 | tamiahua
# Processing Record 19 of Set 12 | khash
# Processing Record 20 of Set 12 | nigde
# Processing Record 21 of Set 12 | camacha
# Processing Record 22 of Set 12 | ahipara
# Processing Record 23 of Set 12 | port augusta
# Processing Record 24 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 25 of Set 12 | northam
# Processing Record 26 of Set 12 | carutapera
# Processing Record 27 of Set 12 | taft
# Processing Record 28 of Set 12 | broken hill
# Processing Record 29 of Set 12 | cockburn town
# Processing Record 30 of Set 12 | jalu
# Processing Record 31 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 12 | azul
# Processing Record 33 of Set 12 | diamantina
# Processing Record 34 of Set 12 | cuenca
# Processing Record 35 of Set 12 | pinerovka
# Processing Record 36 of Set 12 | sudbury
# Processing Record 37 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 38 of Set 12 | kupino
# Processing Record 39 of Set 12 | vardo
# Processing Record 40 of Set 12 | rio grande
# Processing Record 41 of Set 12 | buon me thuot
# City not found. Skipping...
# Processing Record 42 of Set 12 | shitanjing
# Processing Record 43 of Set 12 | tutoia
# Processing Record 44 of Set 12 | krasnousolskiy
# City not found. Skipping...
# Processing Record 45 of Set 12 | kongoussi
# Processing Record 46 of Set 12 | zabid
# Processing Record 47 of Set 12 | sterling
# Processing Record 48 of Set 12 | tateyama
# Processing Record 49 of Set 12 | okha
# Processing Record 50 of Set 12 | gimli
# Processing Record 1 of Set 13 | maputo
# Processing Record 2 of Set 13 | cabanas
# Processing Record 3 of Set 13 | santander
# Processing Record 4 of Set 13 | lima
# Processing Record 5 of Set 13 | ribeira brava
# Processing Record 6 of Set 13 | mount isa
# Processing Record 7 of Set 13 | halol
# Processing Record 8 of Set 13 | majdanpek
# Processing Record 9 of Set 13 | ovsyanka
# Processing Record 10 of Set 13 | necochea
# Processing Record 11 of Set 13 | erenhot
# Processing Record 12 of Set 13 | tiarei
# Processing Record 13 of Set 13 | bandundu
# Processing Record 14 of Set 13 | makat
# Processing Record 15 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 13 | porto novo
# Processing Record 17 of Set 13 | richards bay
# Processing Record 18 of Set 13 | kokkola
# Processing Record 19 of Set 13 | evensk
# Processing Record 20 of Set 13 | susanville
# Processing Record 21 of Set 13 | grenaa
# Processing Record 22 of Set 13 | krasnyy chikoy
# Processing Record 23 of Set 13 | ibra
# Processing Record 24 of Set 13 | lao cai
# Processing Record 25 of Set 13 | klintsy
# Processing Record 26 of Set 13 | paita
# Processing Record 27 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 28 of Set 13 | safaga
# Processing Record 29 of Set 13 | suntar
# Processing Record 30 of Set 13 | hat yai
# Processing Record 31 of Set 13 | bitung
# Processing Record 32 of Set 13 | barroso
# Processing Record 33 of Set 13 | ailigandi
# Processing Record 34 of Set 13 | vancouver
# Processing Record 35 of Set 13 | tanabe
# Processing Record 36 of Set 13 | leshukonskoye
# Processing Record 37 of Set 13 | igarka
# Processing Record 38 of Set 13 | tuyen quang
# Processing Record 39 of Set 13 | agadir
# Processing Record 40 of Set 13 | tarauaca
# Processing Record 41 of Set 13 | matara
# Processing Record 42 of Set 13 | jaisinghnagar
# Processing Record 43 of Set 13 | wanlaweyn
# Processing Record 44 of Set 13 | jiuquan
# Processing Record 45 of Set 13 | les herbiers
# Processing Record 46 of Set 13 | narasannapeta
# Processing Record 47 of Set 13 | palmares do sul
# Processing Record 48 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 49 of Set 13 | nuuk
# Processing Record 50 of Set 13 | bure
# Processing Record 1 of Set 14 | carira
# Processing Record 2 of Set 14 | mamou
# Processing Record 3 of Set 14 | brae
# Processing Record 4 of Set 14 | sept-iles
# Processing Record 5 of Set 14 | ratnagiri
# Processing Record 6 of Set 14 | waingapu
# Processing Record 7 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 14 | guidonia
# Processing Record 9 of Set 14 | xingyi
# Processing Record 10 of Set 14 | bela vista do paraiso
# Processing Record 11 of Set 14 | chany
# Processing Record 12 of Set 14 | mantua
# Processing Record 13 of Set 14 | pallisa
# Processing Record 14 of Set 14 | liling
# Processing Record 15 of Set 14 | santiago
# Processing Record 16 of Set 14 | pipar
# Processing Record 17 of Set 14 | wattegama
# Processing Record 18 of Set 14 | dudinka
# Processing Record 19 of Set 14 | capreol
# Processing Record 20 of Set 14 | havoysund
# Processing Record 21 of Set 14 | bonavista
# Processing Record 22 of Set 14 | pontal do parana
# Processing Record 23 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 14 | waddan
# Processing Record 25 of Set 14 | renqiu
# Processing Record 26 of Set 14 | winnemucca
# Processing Record 27 of Set 14 | polyarnyy
# Processing Record 28 of Set 14 | korla
# Processing Record 29 of Set 14 | lewistown
# Processing Record 30 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 31 of Set 14 | teahupoo
# Processing Record 32 of Set 14 | libenge
# Processing Record 33 of Set 14 | talnakh
# Processing Record 34 of Set 14 | garowe
# Processing Record 35 of Set 14 | formosa
# Processing Record 36 of Set 14 | angoram
# Processing Record 37 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 38 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 39 of Set 14 | oktyabrskiy
# Processing Record 40 of Set 14 | porto nacional
# Processing Record 41 of Set 14 | kenora
# Processing Record 42 of Set 14 | chicama
# Processing Record 43 of Set 14 | canutama
# Processing Record 44 of Set 14 | eskil
# Processing Record 45 of Set 14 | rapid valley
# Processing Record 46 of Set 14 | kirkwall
# Processing Record 47 of Set 14 | marovoay
# Processing Record 48 of Set 14 | caluquembe
# Processing Record 49 of Set 14 | albertville
# Processing Record 50 of Set 14 | araouane
# Processing Record 1 of Set 15 | kota kinabalu
# Processing Record 2 of Set 15 | nkoteng
# Processing Record 3 of Set 15 | blagoyevo
# Processing Record 4 of Set 15 | ouallam
# Processing Record 5 of Set 15 | maralal
# Processing Record 6 of Set 15 | male
# Processing Record 7 of Set 15 | burma
# Processing Record 8 of Set 15 | chinsali
# Processing Record 9 of Set 15 | chapais
# Processing Record 10 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 15 | larap
# Processing Record 12 of Set 15 | mocajuba
# Processing Record 13 of Set 15 | baguanos
# Processing Record 14 of Set 15 | yuma
# Processing Record 15 of Set 15 | pleszew
# Processing Record 16 of Set 15 | farafangana
# Processing Record 17 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 19 of Set 15 | elk city
# Processing Record 20 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 15 | vao
# Processing Record 22 of Set 15 | envira
# Processing Record 23 of Set 15 | bereda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 655
